# %% [markdown]
# <a href="https://colab.research.google.com/github/Jeanpiert/BOT-reciclaje/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install rembg onnxruntime

# %%
# !pip install Pillow==9.0.0

# %%
from rembg import remove
import numpy as np
from google.colab.patches import cv2_imshow
import cv2

# %%
from google.colab import files

uploaded1 = files.upload()
uploaded2 = files.upload()
# Out:
#      <input type="file" id="files-a8d97111-f567-4146-bf9a-822b04dc6ff1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a8d97111-f567-4146-bf9a-822b04dc6ff1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
input_path = '/content/meme.jpg'
output_path = 'output.png'

with open(input_path, 'rb') as i:
  with open(output_path, 'wb') as o:
    input = i.read()
    output = remove(input)
    o.write(output)

# %%
cv2_imshow(cv2.imread('output.png'))
# Out:
# <PIL.Image.Image image mode=RGB size=600x568>

# %%
import numpy as np

def change_back(background, img):
    x, y = 0, 0
    background = cv2.resize(background, (img.shape[1], img.shape[0]), interpolation = cv2.INTER_AREA)
    res = np.copy(background)
    place = res[y: y + img.shape[0], x: x + img.shape[1]]
    a = img[..., 3:].repeat(3, axis=2).astype('uint16')
    place[...] = (place.astype('uint16') * (255 - a) // 255) + img[..., :3].astype('uint16') * a // 255
    return res

# %%
image = cv2.imread('output.png', cv2.IMREAD_UNCHANGED)
back = cv2.imread('/content/meme 2.jpg')
result = change_back(back, image)

# %%
cv2_imshow(result)
# Out:
# <PIL.Image.Image image mode=RGB size=600x568>
